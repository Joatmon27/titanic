# %%
import pandas as pd

# %%
train = pd.read_csv('data/train.csv')
X_train = train.drop('Survived',axis=1)
y_train = train.loc[:,'Survived']

test = pd.read_csv('data/test.csv')
X_test = train.drop('Survived',axis=1)
y_test = train.loc[:,'Survived']

# %%
# Out:
# (891, 11)
